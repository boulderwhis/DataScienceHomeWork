# %% [markdown]
# # Wine

# %% [markdown]
# ### Introduction:
#
# This exercise is a adaptation from the UCI Wine dataset.
# The only pupose is to practice deleting data with pandas.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data).

# %% [markdown]
# ### Step 3. Assign it to a variable called wine

# %%
data = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data'
wine = pd.read_csv(data)

wine.head()
# Out:
#    1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29  5.64  1.04  3.92  \
# 0  1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28  4.38  1.05  3.40
# 1  1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81  5.68  1.03  3.17
# 2  1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18  7.80  0.86  3.45
# 3  1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82  4.32  1.04  2.93
# 4  1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97  6.75  1.05  2.85
#
#    1065
# 0  1050
# 1  1185
# 2  1480
# 3   735
# 4  1450

# %% [markdown]
# ### Step 4. Delete the first, fourth, seventh, nineth, eleventh, thirteenth and fourteenth columns

# %%
wine = wine.drop(wine.columns[[0, 3, 6, 8, 10, 12, 13]], axis = 1)

wine.head()
# Out:
#    14.23  1.71  15.6  127  3.06  2.29  1.04
# 0  13.20  1.78  11.2  100  2.76  1.28  1.05
# 1  13.16  2.36  18.6  101  3.24  2.81  1.03
# 2  14.37  1.95  16.8  113  3.49  2.18  0.86
# 3  13.24  2.59  21.0  118  2.69  1.82  1.04
# 4  14.20  1.76  15.2  112  3.39  1.97  1.05

# %% [markdown]
# ### Step 5. Assign the columns as below:
#
# The attributes are (donated by Riccardo Leardi, riclea '@' anchem.unige.it):
# 1) alcohol
# 2) malic_acid
# 3) alcalinity_of_ash
# 4) magnesium
# 5) flavanoids
# 6) proanthocyanins
# 7) hue

# %%
wine.columns = ['alcohol', 'malic_acid', 'alcalinity_of_ash', 'magnesium', 'flavanoids', 'proanthocyanins', 'hue']
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0    13.20        1.78               11.2        100        2.76
# 1    13.16        2.36               18.6        101        3.24
# 2    14.37        1.95               16.8        113        3.49
# 3    13.24        2.59               21.0        118        2.69
# 4    14.20        1.76               15.2        112        3.39
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05

# %% [markdown]
# ### Step 6. Set the values of the first 3 rows from alcohol as NaN

# %%
wine.iloc[0:3, 0] = np.nan
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      NaN        1.78               11.2        100        2.76
# 1      NaN        2.36               18.6        101        3.24
# 2      NaN        1.95               16.8        113        3.49
# 3    13.24        2.59               21.0        118        2.69
# 4    14.20        1.76               15.2        112        3.39
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05

# %% [markdown]
# ### Step 7. Now set the value of the rows 3 and 4 of magnesium as NaN

# %%
wine.iloc[3:5, 3] = np.nan
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      NaN        1.78               11.2      100.0        2.76
# 1      NaN        2.36               18.6      101.0        3.24
# 2      NaN        1.95               16.8      113.0        3.49
# 3    13.24        2.59               21.0        NaN        2.69
# 4    14.20        1.76               15.2        NaN        3.39
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05

# %% [markdown]
# ### Step 8. Fill the value of NaN with the number 10 in alcohol and 100 in magnesium

# %%
wine.alcohol.fillna(10, inplace=True)
wine.magnesium.fillna(100, inplace=True)
wine.head()
# Out:
#    index  alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      0    10.00        1.78               11.2      100.0        2.76
# 1      2    10.00        1.95               16.8      113.0        3.49
# 2      3    13.24        2.59               21.0      100.0        2.69
# 3     10    14.12        1.48               16.8       95.0        2.43
# 4     11    13.75        1.73               16.0       89.0        2.76
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.18  0.86
# 2             1.82  1.04
# 3             1.57  1.17
# 4             1.81  1.15

# %% [markdown]
# ### Step 9. Count the number of missing values

# %%
sum(wine.isnull().sum())
# Out:
# 0

# %% [markdown]
# ### Step 10.  Create an array of 10 random numbers up until 10

# %%
j = np.random.randint(1,10, size=(10))
# Out:
# [8 6 4 1 6 7 8 9 6 5]

# %% [markdown]
# ### Step 11.  Use random numbers you generated as an index and assign NaN value to each of cell. (this was a bit ambiguous so I set the NaN values into alcalinity_of_ash)

# %%
wine.alcalinity_of_ash[j] = np.nan
wine.head(20)
# Out:
#     alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0     10.00        1.78               11.2      100.0        2.76
# 1     10.00        2.36                NaN      101.0        3.24
# 2     10.00        1.95               16.8      113.0        3.49
# 3     13.24        2.59               21.0      100.0        2.69
# 4     14.20        1.76                NaN      100.0        3.39
# 5     14.39        1.87                NaN       96.0        2.52
# 6     14.06        2.15                NaN      121.0        2.51
# 7     14.83        1.64                NaN       97.0        2.98
# 8     13.86        1.35                NaN       98.0        3.15
# 9     14.10        2.16                NaN      105.0        3.32
# 10    14.12        1.48               16.8       95.0        2.43
# 11    13.75        1.73               16.0       89.0        2.76
# 12    14.75        1.73               11.4       91.0        3.69
# ...

# %% [markdown]
# ### Step 12.  How many missing values do we have?

# %%
sum(wine.isnull().sum())
#less than 10 due to duplicate random number generation
# Out:
# 7

# %% [markdown]
# ### Step 13. Delete the rows that contain missing values

# %%
wine = wine.dropna()
wine.head()
# Out:
#     alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0     10.00        1.78               11.2      100.0        2.76
# 2     10.00        1.95               16.8      113.0        3.49
# 3     13.24        2.59               21.0      100.0        2.69
# 10    14.12        1.48               16.8       95.0        2.43
# 11    13.75        1.73               16.0       89.0        2.76
#
#     proanthocyanins   hue
# 0              1.28  1.05
# 2              2.18  0.86
# 3              1.82  1.04
# 10             1.57  1.17
# 11             1.81  1.15

# %% [markdown]
# ### Step 14. Print only the non-null values in alcohol

# %%
wine.alcalinity_of_ash[wine.alcalinity_of_ash.notnull()]
# Out:
# 0      11.2
# 2      16.8
# 3      21.0
# 10     16.8
# 11     16.0
#        ...
# 172    20.5
# 173    23.0
# 174    20.0
# 175    20.0
# 176    24.5
# Name: alcalinity_of_ash, Length: 170, dtype: float64

# %% [markdown]
# ### Step 15.  Reset the index, so it starts with 0 again

# %%
wine = wine.reset_index()
wine.head(len(wine))
# Out:
#      index  alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0        0    10.00        1.78               11.2      100.0        2.76
# 1        2    10.00        1.95               16.8      113.0        3.49
# 2        3    13.24        2.59               21.0      100.0        2.69
# 3       10    14.12        1.48               16.8       95.0        2.43
# 4       11    13.75        1.73               16.0       89.0        2.76
# ..     ...      ...         ...                ...        ...         ...
# 165    172    13.71        5.65               20.5       95.0        0.61
# 166    173    13.40        3.91               23.0      102.0        0.75
# 167    174    13.27        4.28               20.0      120.0        0.69
# 168    175    13.17        2.59               20.0      120.0        0.68
# 169    176    14.13        4.10               24.5       96.0        0.76
#
#      proanthocyanins   hue
# 0               1.28  1.05
# ...

# %% [markdown]
# ### BONUS: Create your own question and answer it.
